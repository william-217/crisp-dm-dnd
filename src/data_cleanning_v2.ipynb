# %% [markdown]
# LIMPEZA E TRANFORMAÇÃO DOS DADOS (PASSO A PASSO)

# %% [markdown]
# Aqui detalha-se todo o proceso de limpeza e transformação dos dados, para posterior modelação.

# %% [markdown]
# 1. Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Carregar dataset original

# %%
df_origin = pd.read_csv("../Dataset/dnd_dataset.csv")
df_origin.head()
# Out:
#    Unnamed: 0  char_id                name  base_hp  stats_1  stats_2  \
# 0           0        1             Molster        8       11       22
# 1           1        3             Prailak      103       12       17
# 2           2        8           Aurilanax       76       18       10
# 3           3       10  Gamndell Banglebon      127       10       14
# 4           4       19      Bellek Bouncer       52       10       10
#
#    stats_3  stats_4  stats_5  stats_6  ... class_starting_level  \
# 0       11       17       20       12  ...                    4
# 1       18       14       16       16  ...                   20
# 2       16       13       13       16  ...                    7
# 3       16       16       15       18  ...                    2
# 4       15       12       14       10  ...                    6
#
#    subclass_starting         class_other      subclass_other total_level  \
# 0                NaN                 NaN                 NaN           4
# 1  The Great Old One                 NaN                 NaN          20
# 2  Oath of the Crown                 NaN                 NaN           7
# 3                NaN  Bard/Cleric/Wizard  School of Illusion          16
# 4        Life Domain                 NaN                 NaN           6
#
#                                                feats  \
# 0                                                NaN
# 1  Spell Sniper (Bard, Sorcerer, Warlock)/Inferna...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            inventory            date_modified  \
# 0  Adamantine Chain Shirt/Cloak of Protection/Gog...  2022-09-12T19:13:03.29Z
# 1  Bag of Holding/Iron Flask/Studded Leather, +3/...   2021-12-07T21:25:36.9Z
# 2                                             Shield     2021-01-21T16:50:35Z
# 3  Give/Studded Leather/Dagger/Light Hammer/Ink (...     2020-08-06T16:05:07Z
# 4                Shield/Plate/Mace/Potion of Healing     2020-05-15T04:47:59Z
#
#   notes_len     gold
# 0        17   305.00
# 1        60     0.00
# 2         0     0.00
# 3        65  4951.06
# 4         0     0.00
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. Análise da estrutura geral do dataset

# %% [markdown]
#  Aqui observamos os tipos de dados, presença de valores nulos e descrição estatística inicial

# %%
#Estrutura geral e tipo de dados
df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204252 entries, 0 to 1204251
# Data columns (total 23 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Unnamed: 0            1204252 non-null  int64
#  1   char_id               1204252 non-null  int64
#  2   name                  1199602 non-null  object
#  3   base_hp               1204252 non-null  int64
#  4   stats_1               1204252 non-null  int64
#  5   stats_2               1204252 non-null  int64
#  6   stats_3               1204252 non-null  int64
#  7   stats_4               1204252 non-null  int64
#  8   stats_5               1204252 non-null  int64
#  9   stats_6               1204252 non-null  int64
#  10  background            898870 non-null   object
#  11  race                  1204252 non-null  object
#  12  class_starting        1204252 non-null  object
#  13  class_starting_level  1204252 non-null  int64
#  14  subclass_starting     607804 non-null   object
#  15  class_other           78814 non-null    object
#  16  subclass_other        48834 non-null    object
#  17  total_level           1204252 non-null  int64
#  18  feats                 219008 non-null   object
#  19  inventory             832291 non-null   object
#  20  date_modified         1204252 non-null  object
#  21  notes_len             1204252 non-null  int64
#  22  gold                  1204252 non-null  float64
# dtypes: float64(1), int64(12), object(10)
# memory usage: 211.3+ MB

# %%
# Estatistica descritiva do data set original
df_origin.describe()
# Out:
#          Unnamed: 0       char_id       base_hp       stats_1       stats_2  \
# count  1.204252e+06  1.204252e+06  1.204252e+06  1.204252e+06  1.204252e+06
# mean   6.021255e+05  8.760689e+05  2.347389e+01  1.051853e+01  1.153501e+01
# std    3.476378e+05  4.414356e+05  2.677593e+01  4.829688e+00  4.918547e+00
# min    0.000000e+00  1.000000e+00 -6.240000e+02  0.000000e+00  0.000000e+00
# 25%    3.010628e+05  5.446485e+05  8.000000e+00  8.000000e+00  1.000000e+01
# 50%    6.021255e+05  8.185030e+05  1.200000e+01  1.100000e+01  1.300000e+01
# 75%    9.031882e+05  1.188040e+06  2.900000e+01  1.400000e+01  1.500000e+01
# max    1.204251e+06  1.988091e+06  5.000000e+02  3.000000e+01  3.000000e+01
#
#             stats_3       stats_4       stats_5       stats_6  \
# count  1.204252e+06  1.204252e+06  1.204252e+06  1.204252e+06
# mean   1.146815e+01  1.025950e+01  1.091329e+01  1.066623e+01
# std    4.744150e+00  4.565985e+00  4.745979e+00  4.844946e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.100000e+01  8.000000e+00  1.000000e+01  8.000000e+00
# 50%    1.300000e+01  1.100000e+01  1.200000e+01  1.200000e+01
# 75%    1.400000e+01  1.300000e+01  1.400000e+01  1.400000e+01
# max    3.000000e+01  3.000000e+01  3.000000e+01  3.000000e+01
#
#        class_starting_level   total_level     notes_len          gold
# count          1.204252e+06  1.204252e+06  1.204252e+06  1.204252e+06
# mean           3.952510e+00  4.209893e+00  2.440385e+02  1.336151e+06
# std            4.344063e+00  4.640197e+00  9.688915e+02  1.131455e+08
# min            1.000000e+00  1.000000e+00 -3.264000e+04  0.000000e+00
# 25%            1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 50%            2.000000e+00  2.000000e+00  0.000000e+00  0.000000e+00
# 75%            5.000000e+00  5.000000e+00  5.300000e+01  2.500000e+01
# max            2.000000e+01  3.400000e+01  3.259300e+04  2.052099e+10

# %%
df_origin.isnull().sum()
# Out:
# Unnamed: 0                    0
# char_id                       0
# name                       4650
# base_hp                       0
# stats_1                       0
# stats_2                       0
# stats_3                       0
# stats_4                       0
# stats_5                       0
# stats_6                       0
# background               305382
# race                          0
# class_starting                0
# class_starting_level          0
# subclass_starting        596448
# class_other             1125438
# subclass_other          1155418
# total_level                   0
# feats                    985244
# inventory                371961
# date_modified                 0
# notes_len                     0
# gold                          0
# dtype: int64

# %%
df_origin.isna().sum()
# Out:
# Unnamed: 0                    0
# char_id                       0
# name                       4650
# base_hp                       0
# stats_1                       0
# stats_2                       0
# stats_3                       0
# stats_4                       0
# stats_5                       0
# stats_6                       0
# background               305382
# race                          0
# class_starting                0
# class_starting_level          0
# subclass_starting        596448
# class_other             1125438
# subclass_other          1155418
# total_level                   0
# feats                    985244
# inventory                371961
# date_modified                 0
# notes_len                     0
# gold                          0
# dtype: int64

# %% [markdown]
# 4. Verificação manual das colunas

# %%
df_origin.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'char_id',
#  'name',
#  'base_hp',
#  'stats_1',
#  'stats_2',
#  'stats_3',
#  'stats_4',
#  'stats_5',
#  'stats_6',
#  'background',
#  'race',
#  'class_starting',
#  'class_starting_level',
#  'subclass_starting',
#  'class_other',
#  'subclass_other',
#  'total_level',
#  'feats',
#  'inventory',
#  'date_modified',
#  'notes_len',
#  'gold']

# %% [markdown]
# 5. Análise mais detalhada de coluna que achámos importantes

# %%
for col in df_origin.columns:
    print(f"Coluna: {col}")
    print("Tipo:", df_origin[col].dtype)
    print("Valores únicos:", df_origin[col].nunique())
    print(df_origin[col].value_counts(dropna=False).head(5))
    print("\n---\n")
# Out:
# Coluna: Unnamed: 0
# Tipo: int64
# Valores únicos: 1204252
# Unnamed: 0
# 1204251    1
# 0          1
# 1          1
# 2          1
# 3          1
# Name: count, dtype: int64
#
# ---
#
# Coluna: char_id
# Tipo: int64
# Valores únicos: 511272
# char_id
# 608449    6
# 608457    6
# 608464    6
# 608468    6
# 608475    6
# Name: count, dtype: int64
#
# ---
#
# Coluna: name
# Tipo: object
# Valores únicos: 393262
# name
# NaN      4650
# Test     1206
# Bob      1003
# test      505
# Varis     469
# Name: count, dtype: int64
#
# ---
#
# Coluna: base_hp
# Tipo: int64
# Valores únicos: 339
# base_hp
# 8     216849
# 10    146653
# 0     107784
# 6      71225
# 12     65897
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_1
# Tipo: int64
# Valores únicos: 30
# stats_1
# 8     200679
# 15    177714
# 10    149672
# 0     145239
# 12    120819
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_2
# Tipo: int64
# Valores únicos: 28
# stats_2
# 15    212856
# 14    176525
# 13    169066
# 0     146583
# 12    122596
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_3
# Tipo: int64
# Valores únicos: 29
# stats_3
# 14    264529
# 13    216545
# 12    158719
# 0     147461
# 15    128172
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_4
# Tipo: int64
# Valores únicos: 27
# stats_4
# 10    222559
# 12    163158
# 0     147873
# 8     143028
# 13    126520
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_5
# Tipo: int64
# Valores únicos: 28
# stats_5
# 12    179694
# 10    167519
# 14    156389
# 15    148669
# 0     147875
# Name: count, dtype: int64
#
# ---
#
# Coluna: stats_6
# Tipo: int64
# Valores únicos: 28
# stats_6
# 15    163174
# 8     160502
# 10    148305
# 0     147813
# 12    138096
# Name: count, dtype: int64
#
# ---
#
# Coluna: background
# Tipo: object
# Valores únicos: 928
# background
# NaN               305382
# Soldier           149424
# Sage              126462
# Criminal / Spy    124969
# Folk Hero         109377
# Name: count, dtype: int64
#
# ---
#
# Coluna: race
# Tipo: object
# Valores únicos: 1189
# race
# Human       260467
# Elf         194312
# Half-Elf    115163
# Dwarf        89961
# Tiefling     89939
# Name: count, dtype: int64
#
# ---
#
# Coluna: class_starting
# Tipo: object
# Valores únicos: 16
# class_starting
# Fighter    141664
# Rogue      137773
# Ranger     108182
# Paladin     99910
# Wizard      98154
# Name: count, dtype: int64
#
# ---
#
# Coluna: class_starting_level
# Tipo: int64
# Valores únicos: 20
# class_starting_level
# 1    548609
# 3    137330
# 5     98015
# 2     77197
# 4     73710
# Name: count, dtype: int64
#
# ---
#
# Coluna: subclass_starting
# Tipo: object
# Valores únicos: 997
# subclass_starting
# NaN                   596448
# Life Domain            62269
# The Fiend              55832
# Draconic Bloodline     55497
# Champion               35707
# Name: count, dtype: int64
#
# ---
#
# Coluna: class_other
# Tipo: object
# Valores únicos: 983
# class_other
# NaN         1125438
# Warlock       11229
# Fighter        9996
# Rogue          9106
# Sorcerer       6389
# Name: count, dtype: int64
#
# ---
#
# Coluna: subclass_other
# Tipo: object
# Valores únicos: 1760
# subclass_other
# NaN                   1155418
# The Fiend                4213
# Draconic Bloodline       3086
# Champion                 2432
# Life Domain              2212
# Name: count, dtype: int64
#
# ---
#
# Coluna: total_level
# Tipo: int64
# Valores únicos: 24
# total_level
# 1    534837
# 3    132472
# 5     96041
# 2     75333
# 4     71576
# Name: count, dtype: int64
#
# ---
#
# Coluna: feats
# Tipo: object
# Valores únicos: 10990
# feats
# NaN                  985244
# Grappler              63705
# Svirfneblin Magic     11740
# War Caster             7819
# Lucky                  5863
# Name: count, dtype: int64
#
# ---
#
# Coluna: inventory
# Tipo: object
# Valores únicos: 228330
# inventory
# NaN                                                                                                                                                 371961
# Leather/Shortsword/Shortsword/Longbow/Arrows/Backpack/Backpack/Bedroll/Mess Kit/Rations (1 day)/Rope, Hempen (50 feet)/Tinderbox/Torch/Waterskin      9086
# Shield/Chain Mail/Longsword/Handaxe/Handaxe/Backpack/Bedroll/Mess Kit/Rations (1 day)/Rope, Hempen (50 feet)/Tinderbox/Torch/Waterskin                4940
# Leather/Shortsword/Shortsword/Longbow/Arrows/Explorer's Pack                                                                                          4903
# Handaxe/Javelin/Greataxe/Backpack/Bedroll/Mess Kit/Rations (1 day)/Rope, Hempen (50 feet)/Tinderbox/Torch/Waterskin                                   4267
# Name: count, dtype: int64
#
# ---
#
# Coluna: date_modified
# Tipo: object
# Valores únicos: 101591
# date_modified
# 2018-06-29T15:37:47Z        960942
# 2021-02-03T07:00:34Z            57
# 2022-05-22T04:48:13.69Z         17
# 2022-05-22T00:59:57.847Z        16
# 2022-04-26T00:43:59.7Z          16
# Name: count, dtype: int64
#
# ---
#
# Coluna: notes_len
# Tipo: int64
# Valores únicos: 7530
# notes_len
# 0      726451
# 129     26780
# 4       21201
# 20      20702
# 43      16240
# Name: count, dtype: int64
#
# ---
#
# Coluna: gold
# Tipo: float64
# Valores únicos: 38880
# gold
# 0.0     615284
# 10.0    128049
# 15.0     76290
# 25.0     26679
# 20.0     11777
# Name: count, dtype: int64
#
# ---

# %%
#  Esta análise ajudou a identificar colunas com alto número de categorias (ex.: `background`),
#  colunas com muitos valores nulos (ex.: `class_other`, `subclass_other`),
#  colunas de texto irrelevantes (`name`, `feats`, `inventory`) 
# e colunas dependentes da classe (`subclass_starting`, `class_starting_level`), 
# permitindo decidir com base em observações concretas.

# %% [markdown]
# 6. Eliminação de colunas irrelevantes ou possivélmente problemáticas, para o contexto do projecto.

# %%
df = df_origin.drop(columns=[
    'Unnamed: 0',         # indice duplicado
    'char_id', 'name',    # id's e nome irrelevantes 
    'class_starting_level', 'subclass_starting', 'class_other', 'subclass_other', # dependem da classe , podem conter data leaks
    'total_level',        # irrelevante pois é derivado de outras colunas
    'feats', 'inventory', # depende da classe escolhida
    'date_modified', 'notes_len', # metadados irrelevantes
    'gold', # irrelevante pois é derivado de outras colunas
    'background'          # correlacionado com a classe e pode conter data leaks
])

# %% [markdown]
# 7. Renomear nomes das colunas

# %%
df = df.rename(columns={
    'stats_1': 'strength',
    'stats_2': 'dexterity',
    'stats_3': 'constitution',
    'stats_4': 'intelligence',
    'stats_5': 'wisdom',
    'stats_6': 'charisma',
    'race': 'race',
    'class_starting': 'class',
    'base_hp': 'base_hp'
})

# %%
list(df.columns)
# Out:
# ['base_hp',
#  'strength',
#  'dexterity',
#  'constitution',
#  'intelligence',
#  'wisdom',
#  'charisma',
#  'race',
#  'class']

# %% [markdown]
# 8. Verificação dos tipos de dados ( novamente )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204252 entries, 0 to 1204251
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   base_hp       1204252 non-null  int64
#  1   strength      1204252 non-null  int64
#  2   dexterity     1204252 non-null  int64
#  3   constitution  1204252 non-null  int64
#  4   intelligence  1204252 non-null  int64
#  5   wisdom        1204252 non-null  int64
#  6   charisma      1204252 non-null  int64
#  7   race          1204252 non-null  object
#  8   class         1204252 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 82.7+ MB

# %%
# - 'classe' e 'race' estão como object. 
# Converter para 'category' para melhorar a performance.

# %%
df['class'] = df['class'].astype('category')
df['race'] = df['race'].astype('category')

colunas_numericas = ['base_hp', 'strength', 'dexterity', 'constitution', 'intelligence', 'wisdom', 'charisma']
df[colunas_numericas] = df[colunas_numericas].apply(pd.to_numeric)

# %% [markdown]
# 9. Análise e limpeza de valores inválidos (stats e hp)

# %%
(df[colunas_numericas] <= 0).sum()
# Out:
# base_hp         108047
# strength        145239
# dexterity       146583
# constitution    147461
# intelligence    147873
# wisdom          147875
# charisma        147813
# dtype: int64

# %%
df = df[(df[colunas_numericas] > 0).all(axis=1)]
(df[colunas_numericas] <= 0).sum()
# Atributos com valor <=0 são inválidos no D&D 5e. HP negativo também foi identificado já no ponto 2 e foi removido.
# Out:
# base_hp         0
# strength        0
# dexterity       0
# constitution    0
# intelligence    0
# wisdom          0
# charisma        0
# dtype: int64

# %%
df[colunas_numericas].describe()
# Out:
#              base_hp       strength      dexterity   constitution  \
# count  979885.000000  979885.000000  979885.000000  979885.000000
# mean       26.664926      11.935843      13.111889      13.050903
# std        27.394798       3.029396       2.545348       2.163289
# min         1.000000       1.000000       1.000000       1.000000
# 25%         8.000000      10.000000      12.000000      12.000000
# 50%        16.000000      12.000000      13.000000      13.000000
# 75%        34.000000      15.000000      15.000000      14.000000
# max       500.000000      30.000000      30.000000      30.000000
#
#         intelligence         wisdom       charisma
# count  979885.000000  979885.000000  979885.000000
# mean       11.671605      12.425965      12.130477
# std         2.630224       2.571643       2.922447
# min         1.000000       1.000000       1.000000
# 25%        10.000000      10.000000      10.000000
# 50%        12.000000      13.000000      12.000000
# 75%        14.000000      14.000000      15.000000
# max        30.000000      30.000000      30.000000

# %% [markdown]
# 10. Distribuição da variávél alvo 'class'

# %%
plt.figure(figsize=(11,7))
ax = df['class'].value_counts().plot(kind='bar')
plt.title('Distribuição das Classes')
plt.xlabel('Classe')
plt.ylabel('Número de Personagens')
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black')
plt.tight_layout()
plt.show()

# %%
# Tabela de classes e número de personagens:
tabela_classes = df['class'].value_counts().reset_index()
tabela_classes.columns = ['Class', 'Número de Personagens']
print(tabela_classes)
# Out:
#                       Class  Número de Personagens
# 0                   Fighter                 116987
# 1                     Rogue                 114556
# 2                    Ranger                  90138
# 3                   Paladin                  82989
# 4                 Barbarian                  79749
# 5                    Wizard                  79234
# 6                    Cleric                  75750
# 7                      Bard                  71766
# 8                      Monk                  65699
# 9                  Sorcerer                  64344
# 10                  Warlock                  63803
# 11                    Druid                  63196
# 12  Blood Hunter (archived)                  10798
# 13                Artificer                    405
# 14             Blood Hunter                    382
# 15           Artificer (UA)                     89

# %%
# Verifica-se que existem 16 classes diferentes, embora Blood Hunter e Artificer sejam subclasses de outras classes, estejam divididos em 4 classes.
#Iremos agrupar Blood Hunter com Blood Hunter (archived) e Artificier com Artificier (UA)

# %% [markdown]
# 11. Normalizar 'class'

# %%
#Lista de classes oficiais
classes_oficiais = [
    "Barbarian", "Bard", "Cleric", "Druid", "Fighter", "Monk",
    "Paladin", "Ranger", "Rogue", "Sorcerer", "Warlock", "Wizard", "Artificer"
]

# %%
# Valores únicos no dataset
classes_dataset = set(df['class'].unique())

# Quais classes oficiais estão no dataset?
presentes = [c for c in classes_oficiais if c in classes_dataset]
faltam = [c for c in classes_oficiais if c not in classes_dataset]

print("Classes oficiais presentes no dataset:", presentes)
print("Classes oficiais em falta no dataset:", faltam)
# Out:
# Classes oficiais presentes no dataset: ['Barbarian', 'Bard', 'Cleric', 'Druid', 'Fighter', 'Monk', 'Paladin', 'Ranger', 'Rogue', 'Sorcerer', 'Warlock', 'Wizard', 'Artificer']
# Classes oficiais em falta no dataset: []

# %%
# Agrupar Artificer e Blood Hunter
df['class'] = df['class'].replace({
    'Artificer (UA)': 'Artificer',
    'Blood Hunter (archived)': 'Blood Hunter',

})
# Out:
# C:\Users\tomas\AppData\Local\Temp\ipykernel_31296\1458079904.py:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['class'] = df['class'].replace({

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
ax = df['class'].value_counts().plot(kind='bar')
plt.title('Distribuição das Classes após normalização')
plt.xlabel('Classe')
plt.ylabel('Número de Personagens')
plt.tight_layout()

# Adiciona o número exato em cima de cada barra
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
# NOTA IMPRTANTE: usar class_weight='balanced' no modelo para lidar com o desbalanceamento de classes!

# %% [markdown]
# 12. Normalização da 'race'

# %%
# A transformação da variável 'race' será realizada após definição de estratégia de verificaão com recurso a nova tabela conseguida por webscrapping.

# %% [markdown]
# 13. Avaliação final ( ultima verificação)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 979885 entries, 0 to 1204250
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   base_hp       979885 non-null  int64
#  1   strength      979885 non-null  int64
#  2   dexterity     979885 non-null  int64
#  3   constitution  979885 non-null  int64
#  4   intelligence  979885 non-null  int64
#  5   wisdom        979885 non-null  int64
#  6   charisma      979885 non-null  int64
#  7   race          979885 non-null  category
#  8   class         979885 non-null  category
# dtypes: category(2), int64(7)
# memory usage: 62.7 MB

# %%
df.describe()
# Out:
#              base_hp       strength      dexterity   constitution  \
# count  979885.000000  979885.000000  979885.000000  979885.000000
# mean       26.664926      11.935843      13.111889      13.050903
# std        27.394798       3.029396       2.545348       2.163289
# min         1.000000       1.000000       1.000000       1.000000
# 25%         8.000000      10.000000      12.000000      12.000000
# 50%        16.000000      12.000000      13.000000      13.000000
# 75%        34.000000      15.000000      15.000000      14.000000
# max       500.000000      30.000000      30.000000      30.000000
#
#         intelligence         wisdom       charisma
# count  979885.000000  979885.000000  979885.000000
# mean       11.671605      12.425965      12.130477
# std         2.630224       2.571643       2.922447
# min         1.000000       1.000000       1.000000
# 25%        10.000000      10.000000      10.000000
# 50%        12.000000      13.000000      12.000000
# 75%        14.000000      14.000000      15.000000
# max        30.000000      30.000000      30.000000

# %%
df.isnull().sum()
# Out:
# base_hp         0
# strength        0
# dexterity       0
# constitution    0
# intelligence    0
# wisdom          0
# charisma        0
# race            0
# class           0
# dtype: int64

# %%
from random import randint
df.head(randint(0,1204250))
# Out:
#         base_hp  strength  dexterity  constitution  intelligence  wisdom  \
# 0             8        11         22            11            17      20
# 1           103        12         17            18            14      16
# 2            76        18         10            16            13      13
# 3           127        10         14            16            16      15
# 4            52        10         10            15            12      14
# ...         ...       ...        ...           ...           ...     ...
# 622222       22        15         12            13            10      14
# 622223       52        15         14            14             8      12
# 622224       53         8         15            15             8      13
# 622225       10        15          9            13            13      10
# 622227       16        17         15            17            15      16
#
#         charisma        race      class
# 0             12   Aarakocra  Artificer
# 1             16    Tiefling    Warlock
# 2             16     Bugbear    Paladin
# 3             18       Gnome    Warlock
# 4             10    Half-Orc     Cleric
# ...          ...         ...        ...
# 622222         8    Half-Orc    Paladin
# 622223         8  Dragonborn     Ranger
# 622224        12    Half-Elf      Rogue
# 622225        13       Human    Fighter
# 622227        14    Half-Elf    Fighter
#
# [509258 rows x 9 columns]

# %% [markdown]
# 14. Exportação de dataset limpo para trabalho de modelação

# %%
df.to_csv("../Dataset/dnd_dataset_cleanned.csv", index=False)
